# %%
from jira.client import JIRA
options = {'server': "https://hibernate.atlassian.net/"}
jira = JIRA(options, basic_auth=("ossama.kordoghli@ensi-uma.tn", "cOchFOzwM9kPculNOs1p343D"))
data,l=productivity_jira("ANN",jira)

# %%
def productivity_jira(project,jira):
    data=[]
    #data=[{}]
    last_ticket=""
    persons=[]
    i=0
    test=False
    size = 100
    initial = 0
    while True:
        start= initial*size
        issues = jira.search_issues('project={}'.format(project), start,size)
        if len(issues) == 0:
            break
        initial += 1

        if(not test):
            last_ticket=issues[0].key.split("-")[1]
            test=True
        
        for issue in issues:
            for j in range(len(issue.fields.customfield_10050)):
                if(issue.fields.customfield_10050[j].displayName not in persons):  
                    data.append({"name":"","closed tickets":0,"all tickets":0,"remain_tickets":0,"in progress":0,"tickets with issues":0})
                    persons.append(issue.fields.customfield_10050[j].displayName)
                    data[i]["name"]=issue.fields.customfield_10050[j].displayName
   
                    i+=1

                
        for issue in issues:
            for e in data :
                for j in range(len(issue.fields.customfield_10050)):
                    if(issue.fields.customfield_10050[j].displayName==e["name"]):
                        e["all tickets"]+=1
                        if(issue.fields.status.name=='Closed' or issue.fields.status.name=='Resolved') :
                            e["closed tickets"]+=1
                        elif(issue.fields.status.name=='Open') :
                            e["in progress"]+=1
                        #elif(eli andhom mochkla fel resolution)
                            #e["tickets with issues"]+=1
                    e["remain tickets"]=e["all tickets"]-e["closed tickets"] #neksa tickets with issues
        
    return data,last_ticket

# %%
data
# Out:
# [{'name': 'Juraci Paixão Kröhling',
#   'closed tickets': 4,
#   'all tickets': 4,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Diego Plentz',
#   'closed tickets': 32,
#   'all tickets': 32,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'khajaasmath',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'chrisc',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Anthony Patricio',
#   'closed tickets': 4,
#   'all tickets': 4,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Harry Clark',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Alex Gitelman',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Nikita Tovstoles',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Steve Ebersole',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Gail Badner',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Emmanuel Bernard',
#   'closed tickets': 508,
#   'all tickets': 508,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'TobinT',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Hardy Ferentschik',
#   'closed tickets': 14,
#   'all tickets': 14,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Miguel Griffa',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Luis Parravicini',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'sathish kumar .N',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Sylvain Vieujot',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'jimothyc',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'QINGFEIY',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Andrew C. Oliver',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Strong Liu',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Miroslav Havram',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Eduard Martinescu',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'arula',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'lukesh shirkey',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Paul Benedict',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Former user',
#   'closed tickets': 4,
#   'all tickets': 4,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Lars Heyden',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Chris Bredesen',
#   'closed tickets': 5,
#   'all tickets': 5,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Adrian Moos',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Alexandre Dutra',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'David Mansfield',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Sven Woltmann',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Bastian Voigt',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'alvinsa',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'VPC',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Geoffrey De Smet',
#   'closed tickets': 7,
#   'all tickets': 7,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'James Roper',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Cédric Chantepie',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Tim Evers',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Luke Maurer',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Max Hartmann',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jesse Sweetland',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Sebastian Baltes',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Timon Hertli',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Diego Miranda',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jeff Glass',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'M. Lhotellerie',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Earnie Dyke',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Mark Koch',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Nick Heudecker',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'TimT',
#   'closed tickets': 5,
#   'all tickets': 5,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'SASA',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'YuvalB',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Immo Heikkinen',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Priya M',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Hontvári József',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ivo Danihelka',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Gregory Klimov',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'todd orr',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Francisco Philip',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jifeng Liu',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Dirk Lachowski',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Michael Newcomb',
#   'closed tickets': 4,
#   'all tickets': 4,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ezra Epstein',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Max Rydahl Andersen',
#   'closed tickets': 16,
#   'all tickets': 16,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Adam Wozniak',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Christian Bauer',
#   'closed tickets': 39,
#   'all tickets': 39,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'jason',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'taowent',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Mathijs den Burger',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'George Gastaldi',
#   'closed tickets': 4,
#   'all tickets': 4,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'James Carman',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'ChandraP',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Nathan Egge',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Artur Legan',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Dennis Fleurbaaij',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Rich Eggert',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Aleksei Valikov',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Paolo "Nusco" Perrotta',
#   'closed tickets': 4,
#   'all tickets': 4,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'nh hockeyplayer',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Steve Gilbert',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Paul Singleton Kossler',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'PeterM',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'PhilippeP',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Stefan Djurasic',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'sfdss',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Eddie Man',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Li',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'FlorentF',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ville Skyttä',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Shawn Clowater',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'sai sirisha',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Pascal Alberty',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'BrianB',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Loïc LEFEVRE',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ilya Kuleshov',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Amit Kasher',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Saverio Trioni',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Amir Pashazadeh',
#   'closed tickets': 7,
#   'all tickets': 7,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'benoit heinrich',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'David Hay',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'John Sadler',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'MathiasM',
#   'closed tickets': 5,
#   'all tickets': 5,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Mike Desjardins',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'AntonP',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'benjamin morelle',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Loïc Minier',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Nico du Toit',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'SeiS',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Søren Pedersen',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'John Yesberg',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'EugeneH',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Thomas Kubicek',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Christopher G. Stach II',
#   'closed tickets': 5,
#   'all tickets': 5,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'BobB',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'mercatism',
#   'closed tickets': 3,
#   'all tickets': 3,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ahmet A. Akın',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Laurent Perez',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Arnout Engelen',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Gary Moselen',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Andras Keri',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'DanielO',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'm',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Vincent Jenks',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Rakesh Kalra',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Brett Wooldridge',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Matthew Frederes',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Alec Lanter',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'kishorepragada',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jacek Chleborowicz',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Dennis Pettersson',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Santiago Arriaga Noguez',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Edward Costello',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Guilherme de Azevedo Silveira',
#   'closed tickets': 3,
#   'all tickets': 3,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Magnus Heino',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Salvatore Insalaco',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Benjamin Bentmann',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jean Paul Ebejer',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Mark Hobson',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'BarryB',
#   'closed tickets': 3,
#   'all tickets': 3,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Benoit',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'BryanB',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Tim Wood',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ted Bergeron',
#   'closed tickets': 5,
#   'all tickets': 5,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Mike Wilson',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'MikeM',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'PaulP',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ron Piterman',
#   'closed tickets': 3,
#   'all tickets': 3,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'ChristophC',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'P',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Zheng.Duan',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Giampaolo Tomassoni',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Dan Armak',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ole Jørgen Aurebekk',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Amelin Dmitry',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jae Cho',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Michael Kantarovich',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'rerr',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Sergey Vladimirov',
#   'closed tickets': 5,
#   'all tickets': 5,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'CelsoJ',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Daniel Tabuenca',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Pedro Lopez',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Koda Janh',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Adrian Sampaleanu',
#   'closed tickets': 4,
#   'all tickets': 4,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'CLEMENT Sébastien',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'masrawi',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Hani Suleiman',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Pierre Fourès',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Brice Laurencin',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'John Schneider',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Paul Kuit',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'SatishG',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Thomas Weber',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'André J. Rogger',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'bobb',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ilya Liubovich',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jeff Schnitzer',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Todd Orr',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'asdfa',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ashley Collins',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Tristan Tarrant',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Niko Horn',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'neeln',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Andrew Pitt',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Andrey Petrov',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Manoj Agrawal',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Erik Tews',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Thomas Risberg',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Paul Cantrell',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Guido Laures',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Alexander Rupsch',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Chris Rudd',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jimmi Dyson',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Mufaddal',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Rene Stolp',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Heiko Briebrecher',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Prabhakar Rao R',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Douglas Rand',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Dan Corneanu',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Álvaro Queiroz Valente',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Gabriel H',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'tingting chen',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Tarek Hammoud',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Andre Christ',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Kenny Cheang',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'RonnR',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Leonardo Quijano',
#   'closed tickets': 4,
#   'all tickets': 4,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'TiagoT',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Max Power',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Stanislav Mironov',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Mike Lindenblatt',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Steven Verze',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Adam Kramer',
#   'closed tickets': 3,
#   'all tickets': 3,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'ErikG',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jeremy Norris',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Stephen Friedrich',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Sven Schliesing',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Robb Greathouse',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'AlexanderA',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Alexander Langer',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'SergeyS',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'DarrylS',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'CraigC',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Nic Holbrook',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Sam Pullara',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Bill Burke',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'frederic.eynard',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Paul Barry',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Matěj Kraus',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'fdo',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Borys Burnayev',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Filippo',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'PeterP',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Matt Todd',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'WolfgangW',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Damon Feldman',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Michael Bergens',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Peak Dev',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ben Ludkiewicz',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Eric De Prez',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'John',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Christian Mouttet',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'James Rosen',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'PhilP',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Robert Watkins',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'hiberdude',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Daniel Fielder',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Noel Bush',
#   'closed tickets': 3,
#   'all tickets': 3,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'MartinM',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Andrew Eiler',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Dave Brosius',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'George Lindholm',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'RyanD',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Andrew Robinson',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Bit Byter',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jeremy Haile',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'ChrisC',
#   'closed tickets': 9,
#   'all tickets': 9,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Stephen Todd',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Vjeran Marcinko',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Marcio Wesley Borges',
#   'closed tickets': 3,
#   'all tickets': 3,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'IlyaI',
#   'closed tickets': 3,
#   'all tickets': 3,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Geir Hedemark',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Aleksander Blomskøld',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Leszek Gawron',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Rory Winston',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'StephenS',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Dave Brondsema',
#   'closed tickets': 3,
#   'all tickets': 3,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'PatrickP',
#   'closed tickets': 3,
#   'all tickets': 3,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Mattias Arbin',
#   'closed tickets': 5,
#   'all tickets': 5,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Rob Moore',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Tim Fennell',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Steven Grimm',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'GavinG',
#   'closed tickets': 12,
#   'all tickets': 12,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Havoc Pennington',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Owen Taylor',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jens Schumann',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Constantine Voronin',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Erwin Bolwidt',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Gérald Quintana',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ortwin Glück',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Pavel ',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Sergey Generalov',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Aaron Metzger',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Alexis Seigneurin',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Vincenz Braun',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'rajanikar reddy',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Nils',
#   'closed tickets': 3,
#   'all tickets': 3,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Andreas Schildbach',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'HeikoH',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'NicolásN',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Odd Möller',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Levi Hoogenberg',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Gregor Melhorn',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Petr Matejka',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'tHE DPR',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Panagiotis Korros',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Dennis C. Byrne',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'MichaelM',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'mike perham',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Feybesse',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'PÁLFALVI Tamás',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Olaf Lenzmann',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'ThomasT',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Mehran Mehr',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'viju yanose',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Dinko Srkoc',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Filip Jirsák',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Loïc Lefèvre',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'DarrenD',
#   'closed tickets': 3,
#   'all tickets': 3,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Michael Buchholz',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'JackJ',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'ScottS',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jon Wynett',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'BillB',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jakub Torbicki',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Alexei Akhounov',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Eric Berry',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Daniel Serodio',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'RenaudR',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Joshua Davis',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Assaf Berg',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'László Benke',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Serg Prasolov',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jesus Marin',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'cc',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Alain Mahier',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Alexander Portnov',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'MattM',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Logi Ragnarsson',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Maciek Kolesnik',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Tzvetan Mikov',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'A B',
#   'closed tickets': 2,
#   'all tickets': 2,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Adrian',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Alex Talib',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Chris Allen',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Murray Todd Williams',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'ShahidS',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Terran Vigil',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Bruno Aranda',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Jonathan Agaliotis',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'edie',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Ronald Wildenberg',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0},
#  {'name': 'Miguel Hernández',
#   'closed tickets': 1,
#   'all tickets': 1,
#   'remain_tickets': 0,
#   'in progress': 0,
#   'tickets with issues': 0,
#   'remain tickets': 0}]
